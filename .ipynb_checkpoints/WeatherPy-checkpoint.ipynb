# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 617

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    print(city_url)

    # # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:

        response = requests.get(city_url)

        if response.status_code == 200:
            # Parse the JSON and retrieve data
            city_weather = response.json()
    
            # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
            city_lat = city_weather['coord']['lat']
            city_lng = city_weather['coord']['lon']
            city_max_temp = city_weather['main']['temp_max']
            city_humidity = city_weather['main']['humidity']
            city_clouds = city_weather['clouds']['all']
            city_wind = city_weather['wind']['speed']
            city_country = city_weather['sys']['country']
            city_date = city_weather['dt']
    
            # Append the City information into city_data list
            city_data.append({"City": city,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date})
            
             # Print success message
            print(f"Data for {city} retrieved successfully.")

        else:
            print(f"Failed to retrieve data for {city}. HTTP Status Code: {response.status_code}")


    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=yellowknife&units=metric
# Processing Record 1 of Set 1 | yellowknife
# Data for yellowknife retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=grytviken&units=metric
# Processing Record 2 of Set 1 | grytviken
# Data for grytviken retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=yaren&units=metric
# Processing Record 3 of Set 1 | yaren
# Data for yaren retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=polyarnyy&units=metric
# Processing Record 4 of Set 1 | polyarnyy
# Data for polyarnyy retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=geraldton&units=metric
# Processing Record 5 of Set 1 | geraldton
# Data for geraldton retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=anibare&units=metric
# Processing Record 6 of Set 1 | anibare
# Failed to retrieve data for anibare. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=edinburgh of the seven seas&units=metric
# Processing Record 7 of Set 1 | edinburgh of the seven seas
# Data for edinburgh of the seven seas retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=port elizabeth&units=metric
# Processing Record 8 of Set 1 | port elizabeth
# Data for port elizabeth retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=horodnya&units=metric
# Processing Record 9 of Set 1 | horodnya
# Data for horodnya retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=north bend&units=metric
# Processing Record 10 of Set 1 | north bend
# Data for north bend retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=iqaluit&units=metric
# Processing Record 11 of Set 1 | iqaluit
# Data for iqaluit retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=waitangi&units=metric
# Processing Record 12 of Set 1 | waitangi
# Data for waitangi retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=diamantina&units=metric
# Processing Record 13 of Set 1 | diamantina
# Data for diamantina retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=jamul&units=metric
# Processing Record 14 of Set 1 | jamul
# Data for jamul retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=vallenar&units=metric
# Processing Record 15 of Set 1 | vallenar
# Data for vallenar retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=anta&units=metric
# Processing Record 16 of Set 1 | anta
# Data for anta retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=albany&units=metric
# Processing Record 17 of Set 1 | albany
# Data for albany retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=khandyga&units=metric
# Processing Record 18 of Set 1 | khandyga
# Data for khandyga retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=egilsstadir&units=metric
# Processing Record 19 of Set 1 | egilsstadir
# Data for egilsstadir retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=adamstown&units=metric
# Processing Record 20 of Set 1 | adamstown
# Data for adamstown retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=labuan lombok&units=metric
# Processing Record 21 of Set 1 | labuan lombok
# Failed to retrieve data for labuan lombok. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=blackmans bay&units=metric
# Processing Record 22 of Set 1 | blackmans bay
# Data for blackmans bay retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=ghat&units=metric
# Processing Record 23 of Set 1 | ghat
# Data for ghat retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=rehoboth&units=metric
# Processing Record 24 of Set 1 | rehoboth
# Data for rehoboth retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=gatesville&units=metric
# Processing Record 25 of Set 1 | gatesville
# Data for gatesville retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=ar rutbah&units=metric
# Processing Record 26 of Set 1 | ar rutbah
# Data for ar rutbah retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=genhe&units=metric
# Processing Record 27 of Set 1 | genhe
# Data for genhe retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=west island&units=metric
# Processing Record 28 of Set 1 | west island
# Data for west island retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=thompson&units=metric
# Processing Record 29 of Set 1 | thompson
# Data for thompson retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=amarpatan&units=metric
# Processing Record 30 of Set 1 | amarpatan
# Data for amarpatan retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=talnakh&units=metric
# Processing Record 31 of Set 1 | talnakh
# Data for talnakh retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=tralee&units=metric
# Processing Record 32 of Set 1 | tralee
# Data for tralee retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=arthur's town&units=metric
# Processing Record 33 of Set 1 | arthur's town
# Failed to retrieve data for arthur's town. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=port mathurin&units=metric
# Processing Record 34 of Set 1 | port mathurin
# Data for port mathurin retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=acarau&units=metric
# Processing Record 35 of Set 1 | acarau
# Data for acarau retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=port-aux-francais&units=metric
# Processing Record 36 of Set 1 | port-aux-francais
# Data for port-aux-francais retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=georgetown&units=metric
# Processing Record 37 of Set 1 | georgetown
# Data for georgetown retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=lihue&units=metric
# Processing Record 38 of Set 1 | lihue
# Data for lihue retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=tellico village&units=metric
# Processing Record 39 of Set 1 | tellico village
# Failed to retrieve data for tellico village. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=aykhal&units=metric
# Processing Record 40 of Set 1 | aykhal
# Data for aykhal retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=atafu village&units=metric
# Processing Record 41 of Set 1 | atafu village
# Data for atafu village retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=utrik&units=metric
# Processing Record 42 of Set 1 | utrik
# Data for utrik retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=taiohae&units=metric
# Processing Record 43 of Set 1 | taiohae
# Failed to retrieve data for taiohae. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=puerto ayora&units=metric
# Processing Record 44 of Set 1 | puerto ayora
# Data for puerto ayora retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=yangor&units=metric
# Processing Record 45 of Set 1 | yangor
# Failed to retrieve data for yangor. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=margaret river&units=metric
# Processing Record 46 of Set 1 | margaret river
# Data for margaret river retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=new norfolk&units=metric
# Processing Record 47 of Set 1 | new norfolk
# Data for new norfolk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=upata&units=metric
# Processing Record 48 of Set 1 | upata
# Data for upata retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=qamdo&units=metric
# Processing Record 49 of Set 1 | qamdo
# Data for qamdo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sabang&units=metric
# Processing Record 50 of Set 1 | sabang
# Data for sabang retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=nova sintra&units=metric
# Processing Record 0 of Set 2 | nova sintra
# Data for nova sintra retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=tefenni&units=metric
# Processing Record 1 of Set 2 | tefenni
# Data for tefenni retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=viligili&units=metric
# Processing Record 2 of Set 2 | viligili
# Failed to retrieve data for viligili. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sarandi grande&units=metric
# Processing Record 3 of Set 2 | sarandi grande
# Data for sarandi grande retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=bodaybo&units=metric
# Processing Record 4 of Set 2 | bodaybo
# Data for bodaybo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=puerto natales&units=metric
# Processing Record 5 of Set 2 | puerto natales
# Data for puerto natales retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=taulaga&units=metric
# Processing Record 6 of Set 2 | taulaga
# Data for taulaga retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=olonkinbyen&units=metric
# Processing Record 7 of Set 2 | olonkinbyen
# Data for olonkinbyen retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=happy valley-goose bay&units=metric
# Processing Record 8 of Set 2 | happy valley-goose bay
# Data for happy valley-goose bay retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=iwanai&units=metric
# Processing Record 9 of Set 2 | iwanai
# Data for iwanai retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=requena&units=metric
# Processing Record 10 of Set 2 | requena
# Data for requena retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=vilyuchinsk&units=metric
# Processing Record 11 of Set 2 | vilyuchinsk
# Data for vilyuchinsk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=klyuchi&units=metric
# Processing Record 12 of Set 2 | klyuchi
# Data for klyuchi retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=huarmey&units=metric
# Processing Record 13 of Set 2 | huarmey
# Data for huarmey retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=jwaneng&units=metric
# Processing Record 14 of Set 2 | jwaneng
# Data for jwaneng retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=bardai&units=metric
# Processing Record 15 of Set 2 | bardai
# Data for bardai retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=bilibino&units=metric
# Processing Record 16 of Set 2 | bilibino
# Data for bilibino retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sitka&units=metric
# Processing Record 17 of Set 2 | sitka
# Data for sitka retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sisimiut&units=metric
# Processing Record 18 of Set 2 | sisimiut
# Data for sisimiut retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=lembar&units=metric
# Processing Record 19 of Set 2 | lembar
# Failed to retrieve data for lembar. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=afaahiti&units=metric
# Processing Record 20 of Set 2 | afaahiti
# Data for afaahiti retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=el daein&units=metric
# Processing Record 21 of Set 2 | el daein
# Failed to retrieve data for el daein. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=bubaque&units=metric
# Processing Record 22 of Set 2 | bubaque
# Data for bubaque retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=ushuaia&units=metric
# Processing Record 23 of Set 2 | ushuaia
# Data for ushuaia retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=whyalla stuart&units=metric
# Processing Record 24 of Set 2 | whyalla stuart
# Failed to retrieve data for whyalla stuart. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hawaiian paradise park&units=metric
# Processing Record 25 of Set 2 | hawaiian paradise park
# Data for hawaiian paradise park retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=san patricio&units=metric
# Processing Record 26 of Set 2 | san patricio
# Data for san patricio retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hirado&units=metric
# Processing Record 27 of Set 2 | hirado
# Data for hirado retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=nguigmi&units=metric
# Processing Record 28 of Set 2 | nguigmi
# Data for nguigmi retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=papatowai&units=metric
# Processing Record 29 of Set 2 | papatowai
# Data for papatowai retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=stanley&units=metric
# Processing Record 30 of Set 2 | stanley
# Data for stanley retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=peterhead&units=metric
# Processing Record 31 of Set 2 | peterhead
# Data for peterhead retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hovd&units=metric
# Processing Record 32 of Set 2 | hovd
# Data for hovd retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=turgen&units=metric
# Processing Record 33 of Set 2 | turgen
# Data for turgen retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=aitape&units=metric
# Processing Record 34 of Set 2 | aitape
# Data for aitape retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=ma'rib&units=metric
# Processing Record 35 of Set 2 | ma'rib
# Data for ma'rib retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=yerofey pavlovich&units=metric
# Processing Record 36 of Set 2 | yerofey pavlovich
# Data for yerofey pavlovich retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=medvezh'yegorsk&units=metric
# Processing Record 37 of Set 2 | medvezh'yegorsk
# Data for medvezh'yegorsk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=ribeira grande&units=metric
# Processing Record 38 of Set 2 | ribeira grande
# Data for ribeira grande retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=mountain home&units=metric
# Processing Record 39 of Set 2 | mountain home
# Data for mountain home retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=nemuro&units=metric
# Processing Record 40 of Set 2 | nemuro
# Data for nemuro retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=jamestown&units=metric
# Processing Record 41 of Set 2 | jamestown
# Data for jamestown retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=nyurba&units=metric
# Processing Record 42 of Set 2 | nyurba
# Data for nyurba retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kolondieba&units=metric
# Processing Record 43 of Set 2 | kolondieba
# Data for kolondieba retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=namibe&units=metric
# Processing Record 44 of Set 2 | namibe
# Data for namibe retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=la sarre&units=metric
# Processing Record 45 of Set 2 | la sarre
# Data for la sarre retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kilindoni&units=metric
# Processing Record 46 of Set 2 | kilindoni
# Data for kilindoni retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=qaqortoq&units=metric
# Processing Record 47 of Set 2 | qaqortoq
# Data for qaqortoq retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=santa elena de uairen&units=metric
# Processing Record 48 of Set 2 | santa elena de uairen
# Data for santa elena de uairen retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=cable beach&units=metric
# Processing Record 49 of Set 2 | cable beach
# Failed to retrieve data for cable beach. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sarny&units=metric
# Processing Record 0 of Set 3 | sarny
# Data for sarny retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sinabang&units=metric
# Processing Record 1 of Set 3 | sinabang
# Data for sinabang retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=trogir&units=metric
# Processing Record 2 of Set 3 | trogir
# Data for trogir retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=langarud&units=metric
# Processing Record 3 of Set 3 | langarud
# Data for langarud retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=dudinka&units=metric
# Processing Record 4 of Set 3 | dudinka
# Data for dudinka retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=cabo san lucas&units=metric
# Processing Record 5 of Set 3 | cabo san lucas
# Data for cabo san lucas retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=laguna de perlas&units=metric
# Processing Record 6 of Set 3 | laguna de perlas
# Data for laguna de perlas retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sale&units=metric
# Processing Record 7 of Set 3 | sale
# Data for sale retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=ilulissat&units=metric
# Processing Record 8 of Set 3 | ilulissat
# Data for ilulissat retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=mbanza kongo&units=metric
# Processing Record 9 of Set 3 | mbanza kongo
# Data for mbanza kongo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=isangel&units=metric
# Processing Record 10 of Set 3 | isangel
# Data for isangel retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=portland&units=metric
# Processing Record 11 of Set 3 | portland
# Data for portland retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=chinsali&units=metric
# Processing Record 12 of Set 3 | chinsali
# Data for chinsali retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=dunedin&units=metric
# Processing Record 13 of Set 3 | dunedin
# Data for dunedin retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kuala terengganu&units=metric
# Processing Record 14 of Set 3 | kuala terengganu
# Data for kuala terengganu retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=ta`u&units=metric
# Processing Record 15 of Set 3 | ta`u
# Data for ta`u retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sao joao da barra&units=metric
# Processing Record 16 of Set 3 | sao joao da barra
# Data for sao joao da barra retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=midvagur&units=metric
# Processing Record 17 of Set 3 | midvagur
# Data for midvagur retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=saipan&units=metric
# Processing Record 18 of Set 3 | saipan
# Data for saipan retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=vizianagaram&units=metric
# Processing Record 19 of Set 3 | vizianagaram
# Data for vizianagaram retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=arkalyk&units=metric
# Processing Record 20 of Set 3 | arkalyk
# Data for arkalyk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=tiksi&units=metric
# Processing Record 21 of Set 3 | tiksi
# Data for tiksi retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=bethel&units=metric
# Processing Record 22 of Set 3 | bethel
# Data for bethel retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hermanus&units=metric
# Processing Record 23 of Set 3 | hermanus
# Data for hermanus retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=lebu&units=metric
# Processing Record 24 of Set 3 | lebu
# Data for lebu retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=okhotsk&units=metric
# Processing Record 25 of Set 3 | okhotsk
# Data for okhotsk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kiama&units=metric
# Processing Record 26 of Set 3 | kiama
# Data for kiama retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=chibougamau&units=metric
# Processing Record 27 of Set 3 | chibougamau
# Data for chibougamau retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kozhevnikovo&units=metric
# Processing Record 28 of Set 3 | kozhevnikovo
# Data for kozhevnikovo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=tolanaro&units=metric
# Processing Record 29 of Set 3 | tolanaro
# Data for tolanaro retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=uzgen&units=metric
# Processing Record 30 of Set 3 | uzgen
# Data for uzgen retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=coahuayana de hidalgo&units=metric
# Processing Record 31 of Set 3 | coahuayana de hidalgo
# Data for coahuayana de hidalgo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=enewetak&units=metric
# Processing Record 32 of Set 3 | enewetak
# Data for enewetak retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=howrah&units=metric
# Processing Record 33 of Set 3 | howrah
# Data for howrah retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=san antonio de pale&units=metric
# Processing Record 34 of Set 3 | san antonio de pale
# Data for san antonio de pale retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=taseyevo&units=metric
# Processing Record 35 of Set 3 | taseyevo
# Data for taseyevo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=newman&units=metric
# Processing Record 36 of Set 3 | newman
# Data for newman retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=imbituba&units=metric
# Processing Record 37 of Set 3 | imbituba
# Data for imbituba retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=guerrero negro&units=metric
# Processing Record 38 of Set 3 | guerrero negro
# Data for guerrero negro retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kralendijk&units=metric
# Processing Record 39 of Set 3 | kralendijk
# Data for kralendijk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=college&units=metric
# Processing Record 40 of Set 3 | college
# Data for college retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=shagonar&units=metric
# Processing Record 41 of Set 3 | shagonar
# Data for shagonar retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kotka&units=metric
# Processing Record 42 of Set 3 | kotka
# Data for kotka retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=meadow lake&units=metric
# Processing Record 43 of Set 3 | meadow lake
# Data for meadow lake retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=desnogorsk&units=metric
# Processing Record 44 of Set 3 | desnogorsk
# Data for desnogorsk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=messaad&units=metric
# Processing Record 45 of Set 3 | messaad
# Data for messaad retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=san julian&units=metric
# Processing Record 46 of Set 3 | san julian
# Data for san julian retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=invercargill&units=metric
# Processing Record 47 of Set 3 | invercargill
# Data for invercargill retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=anadyr&units=metric
# Processing Record 48 of Set 3 | anadyr
# Data for anadyr retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=silapathar&units=metric
# Processing Record 49 of Set 3 | silapathar
# Data for silapathar retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=longyearbyen&units=metric
# Processing Record 0 of Set 4 | longyearbyen
# Data for longyearbyen retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hithadhoo&units=metric
# Processing Record 1 of Set 4 | hithadhoo
# Data for hithadhoo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=iskateley&units=metric
# Processing Record 2 of Set 4 | iskateley
# Data for iskateley retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=cidreira&units=metric
# Processing Record 3 of Set 4 | cidreira
# Data for cidreira retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=khanty-mansiysk&units=metric
# Processing Record 4 of Set 4 | khanty-mansiysk
# Data for khanty-mansiysk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=san juan del sur&units=metric
# Processing Record 5 of Set 4 | san juan del sur
# Data for san juan del sur retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=lodja&units=metric
# Processing Record 6 of Set 4 | lodja
# Data for lodja retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=abra pampa&units=metric
# Processing Record 7 of Set 4 | abra pampa
# Data for abra pampa retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=recani&units=metric
# Processing Record 8 of Set 4 | recani
# Data for recani retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=victoria point&units=metric
# Processing Record 9 of Set 4 | victoria point
# Data for victoria point retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=westport&units=metric
# Processing Record 10 of Set 4 | westport
# Data for westport retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=whitehorse&units=metric
# Processing Record 11 of Set 4 | whitehorse
# Data for whitehorse retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=camana&units=metric
# Processing Record 12 of Set 4 | camana
# Data for camana retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=fale old settlement&units=metric
# Processing Record 13 of Set 4 | fale old settlement
# Data for fale old settlement retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=bel ombre&units=metric
# Processing Record 14 of Set 4 | bel ombre
# Data for bel ombre retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=isafjordur&units=metric
# Processing Record 15 of Set 4 | isafjordur
# Data for isafjordur retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=muynoq&units=metric
# Processing Record 16 of Set 4 | muynoq
# Data for muynoq retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=keflavik&units=metric
# Processing Record 17 of Set 4 | keflavik
# Data for keflavik retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=yuzhno-kurilsk&units=metric
# Processing Record 18 of Set 4 | yuzhno-kurilsk
# Data for yuzhno-kurilsk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=saacow&units=metric
# Processing Record 19 of Set 4 | saacow
# Data for saacow retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=anna regina&units=metric
# Processing Record 20 of Set 4 | anna regina
# Data for anna regina retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=itaguai&units=metric
# Processing Record 21 of Set 4 | itaguai
# Data for itaguai retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kerikeri&units=metric
# Processing Record 22 of Set 4 | kerikeri
# Data for kerikeri retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=mailsi&units=metric
# Processing Record 23 of Set 4 | mailsi
# Data for mailsi retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=igoumenitsa&units=metric
# Processing Record 24 of Set 4 | igoumenitsa
# Data for igoumenitsa retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=savastepe&units=metric
# Processing Record 25 of Set 4 | savastepe
# Data for savastepe retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=port alfred&units=metric
# Processing Record 26 of Set 4 | port alfred
# Data for port alfred retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=yangambi&units=metric
# Processing Record 27 of Set 4 | yangambi
# Data for yangambi retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=yeniseysk&units=metric
# Processing Record 28 of Set 4 | yeniseysk
# Data for yeniseysk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=akjoujt&units=metric
# Processing Record 29 of Set 4 | akjoujt
# Data for akjoujt retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=long beach&units=metric
# Processing Record 30 of Set 4 | long beach
# Data for long beach retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=ambon&units=metric
# Processing Record 31 of Set 4 | ambon
# Data for ambon retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=souillac&units=metric
# Processing Record 32 of Set 4 | souillac
# Data for souillac retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=crane&units=metric
# Processing Record 33 of Set 4 | crane
# Data for crane retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=walvis bay&units=metric
# Processing Record 34 of Set 4 | walvis bay
# Data for walvis bay retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=avarua&units=metric
# Processing Record 35 of Set 4 | avarua
# Data for avarua retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=wailua homesteads&units=metric
# Processing Record 36 of Set 4 | wailua homesteads
# Data for wailua homesteads retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=broome&units=metric
# Processing Record 37 of Set 4 | broome
# Data for broome retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=la passe&units=metric
# Processing Record 38 of Set 4 | la passe
# Data for la passe retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=egersund&units=metric
# Processing Record 39 of Set 4 | egersund
# Data for egersund retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=vyalikaya byerastavitsa&units=metric
# Processing Record 40 of Set 4 | vyalikaya byerastavitsa
# Data for vyalikaya byerastavitsa retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=palikir - national government center&units=metric
# Processing Record 41 of Set 4 | palikir - national government center
# Data for palikir - national government center retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=fortaleza&units=metric
# Processing Record 42 of Set 4 | fortaleza
# Data for fortaleza retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=arraial do cabo&units=metric
# Processing Record 43 of Set 4 | arraial do cabo
# Data for arraial do cabo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=borogontsy&units=metric
# Processing Record 44 of Set 4 | borogontsy
# Data for borogontsy retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=bredasdorp&units=metric
# Processing Record 45 of Set 4 | bredasdorp
# Data for bredasdorp retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kalemie&units=metric
# Processing Record 46 of Set 4 | kalemie
# Data for kalemie retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=callao&units=metric
# Processing Record 47 of Set 4 | callao
# Data for callao retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=pisco&units=metric
# Processing Record 48 of Set 4 | pisco
# Data for pisco retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=luwingu&units=metric
# Processing Record 49 of Set 4 | luwingu
# Data for luwingu retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=punta arenas&units=metric
# Processing Record 0 of Set 5 | punta arenas
# Data for punta arenas retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=badger&units=metric
# Processing Record 1 of Set 5 | badger
# Data for badger retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=krasnogvardeyskoye&units=metric
# Processing Record 2 of Set 5 | krasnogvardeyskoye
# Data for krasnogvardeyskoye retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=gizo&units=metric
# Processing Record 3 of Set 5 | gizo
# Data for gizo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=klein reken&units=metric
# Processing Record 4 of Set 5 | klein reken
# Data for klein reken retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hamilton&units=metric
# Processing Record 5 of Set 5 | hamilton
# Data for hamilton retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=beykonak&units=metric
# Processing Record 6 of Set 5 | beykonak
# Data for beykonak retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=aasiaat&units=metric
# Processing Record 7 of Set 5 | aasiaat
# Data for aasiaat retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hobyo&units=metric
# Processing Record 8 of Set 5 | hobyo
# Data for hobyo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sangsong-ni&units=metric
# Processing Record 9 of Set 5 | sangsong-ni
# Data for sangsong-ni retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=prince george&units=metric
# Processing Record 10 of Set 5 | prince george
# Data for prince george retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=fang&units=metric
# Processing Record 11 of Set 5 | fang
# Data for fang retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hurricane&units=metric
# Processing Record 12 of Set 5 | hurricane
# Data for hurricane retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=st. john's&units=metric
# Processing Record 13 of Set 5 | st. john's
# Data for st. john's retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sola&units=metric
# Processing Record 14 of Set 5 | sola
# Data for sola retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=holma&units=metric
# Processing Record 15 of Set 5 | holma
# Data for holma retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=ibshaway&units=metric
# Processing Record 16 of Set 5 | ibshaway
# Data for ibshaway retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=udachny&units=metric
# Processing Record 17 of Set 5 | udachny
# Data for udachny retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=tranovaho&units=metric
# Processing Record 18 of Set 5 | tranovaho
# Failed to retrieve data for tranovaho. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=alofi&units=metric
# Processing Record 19 of Set 5 | alofi
# Data for alofi retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=freetown&units=metric
# Processing Record 20 of Set 5 | freetown
# Data for freetown retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=charlestown&units=metric
# Processing Record 21 of Set 5 | charlestown
# Data for charlestown retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=nogliki&units=metric
# Processing Record 22 of Set 5 | nogliki
# Data for nogliki retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=playa del ingles&units=metric
# Processing Record 23 of Set 5 | playa del ingles
# Data for playa del ingles retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=pathein&units=metric
# Processing Record 24 of Set 5 | pathein
# Data for pathein retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=el calafate&units=metric
# Processing Record 25 of Set 5 | el calafate
# Data for el calafate retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=faya-largeau&units=metric
# Processing Record 26 of Set 5 | faya-largeau
# Data for faya-largeau retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=haiku-pauwela&units=metric
# Processing Record 27 of Set 5 | haiku-pauwela
# Data for haiku-pauwela retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kharp&units=metric
# Processing Record 28 of Set 5 | kharp
# Data for kharp retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q='ohonua&units=metric
# Processing Record 29 of Set 5 | 'ohonua
# Failed to retrieve data for 'ohonua. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=greymouth&units=metric
# Processing Record 30 of Set 5 | greymouth
# Data for greymouth retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=san mariano&units=metric
# Processing Record 31 of Set 5 | san mariano
# Data for san mariano retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=salaqi&units=metric
# Processing Record 32 of Set 5 | salaqi
# Data for salaqi retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=fairbanks&units=metric
# Processing Record 33 of Set 5 | fairbanks
# Data for fairbanks retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hashtrud&units=metric
# Processing Record 34 of Set 5 | hashtrud
# Data for hashtrud retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=anaco&units=metric
# Processing Record 35 of Set 5 | anaco
# Data for anaco retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=mareeba&units=metric
# Processing Record 36 of Set 5 | mareeba
# Data for mareeba retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=verkhnevilyuysk&units=metric
# Processing Record 37 of Set 5 | verkhnevilyuysk
# Data for verkhnevilyuysk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=gorontalo&units=metric
# Processing Record 38 of Set 5 | gorontalo
# Data for gorontalo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sao tome&units=metric
# Processing Record 39 of Set 5 | sao tome
# Data for sao tome retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=iznalloz&units=metric
# Processing Record 40 of Set 5 | iznalloz
# Data for iznalloz retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=envira&units=metric
# Processing Record 41 of Set 5 | envira
# Data for envira retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kavieng&units=metric
# Processing Record 42 of Set 5 | kavieng
# ...
# Processing Record 36 of Set 11 | myeik
# Data for myeik retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kamiiso&units=metric
# Processing Record 37 of Set 11 | kamiiso
# Data for kamiiso retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=shimoda&units=metric
# Processing Record 38 of Set 11 | shimoda
# Data for shimoda retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=muang xay&units=metric
# Processing Record 39 of Set 11 | muang xay
# Data for muang xay retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=vicuna mackenna&units=metric
# Processing Record 40 of Set 11 | vicuna mackenna
# Data for vicuna mackenna retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=cadale&units=metric
# Processing Record 41 of Set 11 | cadale
# Data for cadale retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=quang ngai&units=metric
# Processing Record 42 of Set 11 | quang ngai
# Data for quang ngai retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hasaki&units=metric
# Processing Record 43 of Set 11 | hasaki
# Data for hasaki retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=emerald&units=metric
# Processing Record 44 of Set 11 | emerald
# Data for emerald retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=igarka&units=metric
# Processing Record 45 of Set 11 | igarka
# Data for igarka retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=bahia de caraquez&units=metric
# Processing Record 46 of Set 11 | bahia de caraquez
# Data for bahia de caraquez retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=xinqing&units=metric
# Processing Record 47 of Set 11 | xinqing
# Data for xinqing retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=baharly&units=metric
# Processing Record 48 of Set 11 | baharly
# Data for baharly retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=merizo village&units=metric
# Processing Record 49 of Set 11 | merizo village
# Data for merizo village retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=colonia&units=metric
# Processing Record 0 of Set 12 | colonia
# Data for colonia retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=al jawf&units=metric
# Processing Record 1 of Set 12 | al jawf
# Data for al jawf retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=mount gambier&units=metric
# Processing Record 2 of Set 12 | mount gambier
# Data for mount gambier retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=onguday&units=metric
# Processing Record 3 of Set 12 | onguday
# Data for onguday retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=zemio&units=metric
# Processing Record 4 of Set 12 | zemio
# Data for zemio retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=as sulayyil&units=metric
# Processing Record 5 of Set 12 | as sulayyil
# Data for as sulayyil retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=chaykovskiy&units=metric
# Processing Record 6 of Set 12 | chaykovskiy
# Data for chaykovskiy retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=santa vitoria do palmar&units=metric
# Processing Record 7 of Set 12 | santa vitoria do palmar
# Data for santa vitoria do palmar retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hailey&units=metric
# Processing Record 8 of Set 12 | hailey
# Data for hailey retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=shalqar&units=metric
# Processing Record 9 of Set 12 | shalqar
# Data for shalqar retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=carnarvon&units=metric
# Processing Record 10 of Set 12 | carnarvon
# Data for carnarvon retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=port lincoln&units=metric
# Processing Record 11 of Set 12 | port lincoln
# Data for port lincoln retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=necochea&units=metric
# Processing Record 12 of Set 12 | necochea
# Data for necochea retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=tabou&units=metric
# Processing Record 13 of Set 12 | tabou
# Data for tabou retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hilo&units=metric
# Processing Record 14 of Set 12 | hilo
# Data for hilo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=arteche&units=metric
# Processing Record 15 of Set 12 | arteche
# Data for arteche retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=newport&units=metric
# Processing Record 16 of Set 12 | newport
# Data for newport retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=mugia&units=metric
# Processing Record 17 of Set 12 | mugia
# Data for mugia retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=bejubang dua&units=metric
# Processing Record 18 of Set 12 | bejubang dua
# Failed to retrieve data for bejubang dua. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=saudarkrokur&units=metric
# Processing Record 19 of Set 12 | saudarkrokur
# Data for saudarkrokur retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sungailiat&units=metric
# Processing Record 20 of Set 12 | sungailiat
# Data for sungailiat retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sergeyevka&units=metric
# Processing Record 21 of Set 12 | sergeyevka
# Data for sergeyevka retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=st ives&units=metric
# Processing Record 22 of Set 12 | st ives
# Data for st ives retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sanchazi&units=metric
# Processing Record 23 of Set 12 | sanchazi
# Data for sanchazi retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=ocean city&units=metric
# Processing Record 24 of Set 12 | ocean city
# Data for ocean city retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kapa'a&units=metric
# Processing Record 25 of Set 12 | kapa'a
# Data for kapa'a retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=zhanibek&units=metric
# Processing Record 26 of Set 12 | zhanibek
# Data for zhanibek retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=katsuren-haebaru&units=metric
# Processing Record 27 of Set 12 | katsuren-haebaru
# Data for katsuren-haebaru retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kill devil hills&units=metric
# Processing Record 28 of Set 12 | kill devil hills
# Data for kill devil hills retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=fuvahmulah&units=metric
# Processing Record 29 of Set 12 | fuvahmulah
# Failed to retrieve data for fuvahmulah. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kataragama&units=metric
# Processing Record 30 of Set 12 | kataragama
# Failed to retrieve data for kataragama. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=leninskoye&units=metric
# Processing Record 31 of Set 12 | leninskoye
# Data for leninskoye retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=khorixas&units=metric
# Processing Record 32 of Set 12 | khorixas
# Data for khorixas retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=galesong&units=metric
# Processing Record 33 of Set 12 | galesong
# Data for galesong retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=tommot&units=metric
# Processing Record 34 of Set 12 | tommot
# Data for tommot retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=wenchang&units=metric
# Processing Record 35 of Set 12 | wenchang
# Data for wenchang retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=dzhubga&units=metric
# Processing Record 36 of Set 12 | dzhubga
# Data for dzhubga retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=yunguyo&units=metric
# Processing Record 37 of Set 12 | yunguyo
# Data for yunguyo retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=san rafael&units=metric
# Processing Record 38 of Set 12 | san rafael
# Data for san rafael retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=daru&units=metric
# Processing Record 39 of Set 12 | daru
# Data for daru retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=taoyuan city&units=metric
# Processing Record 40 of Set 12 | taoyuan city
# Data for taoyuan city retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=buncrana&units=metric
# Processing Record 41 of Set 12 | buncrana
# Data for buncrana retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=altofonte&units=metric
# Processing Record 42 of Set 12 | altofonte
# Data for altofonte retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=labrador city&units=metric
# Processing Record 43 of Set 12 | labrador city
# Data for labrador city retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=las vegas&units=metric
# Processing Record 44 of Set 12 | las vegas
# Data for las vegas retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sorsk&units=metric
# Processing Record 45 of Set 12 | sorsk
# Data for sorsk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=warwick&units=metric
# Processing Record 46 of Set 12 | warwick
# Data for warwick retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=tazacorte&units=metric
# Processing Record 47 of Set 12 | tazacorte
# Data for tazacorte retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=tazovsky&units=metric
# Processing Record 48 of Set 12 | tazovsky
# Data for tazovsky retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=ghanzi&units=metric
# Processing Record 49 of Set 12 | ghanzi
# Data for ghanzi retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=banda aceh&units=metric
# Processing Record 0 of Set 13 | banda aceh
# Data for banda aceh retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=dolinsk&units=metric
# Processing Record 1 of Set 13 | dolinsk
# Data for dolinsk retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=puerto cabezas&units=metric
# Processing Record 2 of Set 13 | puerto cabezas
# Data for puerto cabezas retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=saint croix&units=metric
# Processing Record 3 of Set 13 | saint croix
# Data for saint croix retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=fort wellington&units=metric
# Processing Record 4 of Set 13 | fort wellington
# Data for fort wellington retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=daventry&units=metric
# Processing Record 5 of Set 13 | daventry
# Data for daventry retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=hotan&units=metric
# Processing Record 6 of Set 13 | hotan
# Data for hotan retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=lata&units=metric
# Processing Record 7 of Set 13 | lata
# Data for lata retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=gisborne&units=metric
# Processing Record 8 of Set 13 | gisborne
# Data for gisborne retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=ahau&units=metric
# Processing Record 9 of Set 13 | ahau
# Failed to retrieve data for ahau. HTTP Status Code: 404
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=silute&units=metric
# Processing Record 10 of Set 13 | silute
# Data for silute retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=sogndal&units=metric
# Processing Record 11 of Set 13 | sogndal
# Data for sogndal retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=campamento&units=metric
# Processing Record 12 of Set 13 | campamento
# Data for campamento retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=kristiansund&units=metric
# Processing Record 13 of Set 13 | kristiansund
# Data for kristiansund retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=auch&units=metric
# Processing Record 14 of Set 13 | auch
# Data for auch retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=luderitz&units=metric
# Processing Record 15 of Set 13 | luderitz
# Data for luderitz retrieved successfully.
# http://api.openweathermap.org/data/2.5/weather?appid=0897fff600bce9876dd45fd191394272&q=garissa&units=metric
# Processing Record 16 of Set 13 | garissa
# Data for garissa retrieved successfully.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          589
# Lat           589
# Lng           589
# Max Temp      589
# Humidity      589
# Cloudiness    589
# Wind Speed    589
# Country       589
# Date          589
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  yellowknife  62.4560 -114.3525     15.31        78          42        4.47
# 1    grytviken -54.2811  -36.5092     -1.28        86         100        6.62
# 2        yaren  -0.5472  166.9160     29.30        69          51        6.16
# 3    polyarnyy  69.1989   33.4478     11.19        83          15        4.51
# 4    geraldton -28.7667  114.6000     16.23        63           0        4.63
#
#   Country        Date
# 0      CA  1722658089
# 1      GS  1722658090
# 2      NR  1722658092
# 3      RU  1722658093
# 4      AU  1722658094

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        yellowknife  62.4560 -114.3525     15.31        78          42
# 1          grytviken -54.2811  -36.5092     -1.28        86         100
# 2              yaren  -0.5472  166.9160     29.30        69          51
# 3          polyarnyy  69.1989   33.4478     11.19        83          15
# 4          geraldton -28.7667  114.6000     16.23        63           0
#
#          Wind Speed Country        Date
# City_ID
# 0              4.47      CA  1722658089
# 1              6.62      GS  1722658090
# 2              6.16      NR  1722658092
# 3              4.51      RU  1722658093
# 4              4.63      AU  1722658094

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# x_values = city_data_df['Lat']
# y_values = city_data_df['Max Temp']
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

def create_linear_regression_plot(x_values, y_values, title, xlabel, ylabel, save_path=None):
   
    # Perform linear regression
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
    
    # Calculate regression values
    regress_values = slope * x_values + intercept
    
    # Create the line equation string
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"
    
    # Create scatter plot and regression line
    plt.scatter(x_values, y_values, label='Data Points')
    plt.plot(x_values,regress_values,"r-", label='Fit Line')
    plt.annotate(line_eq, (5.8,0.8),fontsize=15, color="red")
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()
    plt.show()

    # Close the plot to avoid overlap in Jupyter Notebook
    # plt.close()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] > 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        yellowknife  62.4560 -114.3525     15.31        78          42
# 3          polyarnyy  69.1989   33.4478     11.19        83          15
# 7           horodnya  51.8909   31.5974     15.99        71          95
# 8         north bend  43.4065 -124.2243     18.48        94         100
# 9            iqaluit  63.7506  -68.5145      4.83        65          17
#
#          Wind Speed Country        Date
# City_ID
# 0              4.47      CA  1722658089
# 3              4.51      RU  1722658093
# 7              1.64      UA  1722658099
# 8              3.60      US  1722658101
# 9              0.90      CA  1722658102

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] > 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        yellowknife  62.4560 -114.3525     15.31        78          42
# 3          polyarnyy  69.1989   33.4478     11.19        83          15
# 7           horodnya  51.8909   31.5974     15.99        71          95
# 8         north bend  43.4065 -124.2243     18.48        94         100
# 9            iqaluit  63.7506  -68.5145      4.83        65          17
#
#          Wind Speed Country        Date
# City_ID
# 0              4.47      CA  1722658089
# 3              4.51      RU  1722658093
# 7              1.64      UA  1722658099
# 8              3.60      US  1722658101
# 9              0.90      CA  1722658102

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
create_linear_regression_plot(
    x_values,
    y_values,
    title="Latitude vs. Max Temp (Northern Hemisphere)",
    xlabel="Latitude",
    ylabel="Max Temp",
)

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
create_linear_regression_plot(
    x_values,
    y_values,
    title="Latitude vs. Max Temp (Southern Hemisphere)",
    xlabel="Latitude",
    ylabel="Max Temp",
)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
create_linear_regression_plot(
    x_values,
    y_values,
    title="Latitude vs.Humidity (Northern Hemisphere)",
    xlabel="Latitude",
    ylabel="Humidity",
)

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
create_linear_regression_plot(
    x_values,
    y_values,
    title="Latitude vs. Humidity (Southern Hemisphere)",
    xlabel="Latitude",
    ylabel="Humidity",
)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
create_linear_regression_plot(
    x_values,
    y_values,
    title="Latitude vs. Cloudiness (Northern Hemisphere)",
    xlabel="Latitude",
    ylabel="Cloudiness",
)

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
create_linear_regression_plot(
    x_values,
    y_values,
    title="Latitude vs. Max Temp (Southern Hemisphere)",
    xlabel="Latitude",
    ylabel="Cloudiness",
)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
create_linear_regression_plot(
    x_values,
    y_values,
    title="Latitude vs. Wind Speed (Northern Hemisphere)",
    xlabel="Latitude",
    ylabel="Wind Speed",
)

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
create_linear_regression_plot(
    x_values,
    y_values,
    title="Latitude vs. Wind Speed (Southern Hemisphere)",
    xlabel="Latitude",
    ylabel="Wind Speed",
)

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
